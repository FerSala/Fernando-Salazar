# %% [markdown]
#  # Matemática para ciencia de los Datos
#  # Trabajo Práctico 1 (TP01)
#
#  Estudiante: Fernando Salazar Arguedas
#
#  Cédula: 207160883

# %% [markdown]
# ---
# **Pregunta 1 (15 puntos, 5 pts c/u)**
#
# Demostrar si los sistemas son líneales o no líneales:
#
#  **a)**$g\left(t\right)=\log _{10} u(t)$
#
#  $log _{10}\left(\alpha u_{1}(t)+\beta u_{2}(t)\right)$ $=?$ $\alpha\,log _{10}\,u_{1}(t)+\beta\,log _{10}\,u_{2}(t)$
#
#  $log _{10}\alpha+log _{10}u_{1}(t)+log _{10}\beta+log _{10}u_{2}(t)$  $=?$  $\alpha\,log _{10}\,u_{1}(t)+\beta\,log _{10}\,u_{2}(t)$
#
#  Por lo tanto el sistema es no líneal.
#
#
#
#
#   **b)**$g\left(t\right)= |u(t) |$
#
#   $1\left(\alpha |u_{1}(t)|+\beta |u_{2}(t)|\right)$ $=?$ $\alpha\,1\,|u_{1}(t)|+\beta\,1\,|u_{2}(t)|$
#
#   $1\alpha\,|u_{1}(t)|+1\beta\,|u_{2}(t)|$  $=?$  $\alpha\,1\,|u_{1}(t)|+\beta\,1\,|u_{2}(t)|$
#
#   $\alpha\,1\,|u_{1}(t)|+\beta\,1 |u_{2}(t)|=\alpha\,1\,|u_{1}(t)|+\beta\,1\,|u_{2}(t)|$
#
#
#   Por lo tanto el sistema es líneal.
#
#
#
#
#   **c)** $g\left(t\right)= \tanh(u(t))=\frac{e^{u(t)}-e^{-u(t)}}{e^{u(t)}+e^{-u(t)}} $
